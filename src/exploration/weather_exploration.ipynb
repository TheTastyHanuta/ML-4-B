# %% [markdown]
# # Weather Exploration

# %%
# Import libraries
import pandas as pd
from datetime import datetime

# %%
# Load weather data from json
#df_weather = pd.read_json('../weatherdata/data_scraping/scrapedData/scrapedData.json')
with open('../weatherdata/data_scraping/scrapedData/scrapedData.json', 'r') as file:
    data = pd.read_json(file)

# %%
# transform the data to a more usable format
records = []
for station, entries in data.items():
    for entry in entries:
        dt = datetime.fromtimestamp(entry['dt'])
        temp_k = entry['main']['temp']
        temp_c = temp_k - 273.15  # Convert from Kelvin to Celsius
        weather_desc = entry['weather'][0]['description'] if entry.get('weather') else None
        rain_amount = entry.get('rain', {}).get('1h', 0.0)
        snow_amount = entry.get('snow', {}).get('1h', 0.0)
        humidity = entry['main']['humidity']
        wind_speed = entry['wind']['speed']
        records.append({
            'station': station,
            'time': dt,
            'temp_celsius': round(temp_c, 2),
            'humidity': humidity,
            'wind_speed': wind_speed,
            'weather': weather_desc,
            'rain_amount': rain_amount,
            'snow_amount': snow_amount
        })

# Create DataFrame
df = pd.DataFrame(records)

# %%
df.shape
# Out:
# (3511, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3511 entries, 0 to 3510
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station       3511 non-null   object
#  1   time          3511 non-null   datetime64[ns]
#  2   temp_celsius  3511 non-null   float64
#  3   humidity      3511 non-null   int64
#  4   wind_speed    3511 non-null   float64
#  5   weather       3511 non-null   object
#  6   rain_amount   3511 non-null   float64
#  7   snow_amount   3511 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 219.6+ KB

# %%
# Display first 5 rows
df.head(15)
# Out:
#                  station                time  temp_celsius  humidity  \
# 0   Berlin Gesundbrunnen 2025-01-01 00:00:00          4.36        93
# 1   Berlin Gesundbrunnen 2025-01-01 01:00:00          4.84        81
# 2   Berlin Gesundbrunnen 2025-01-01 02:00:00          5.45        83
# 3   Berlin Gesundbrunnen 2025-01-01 03:00:00          5.42        84
# 4   Berlin Gesundbrunnen 2025-01-01 04:00:00          5.92        84
# 5   Berlin Gesundbrunnen 2025-01-01 05:00:00          6.53        86
# 6   Berlin Gesundbrunnen 2025-01-01 06:00:00          6.59        87
# 7   Berlin Gesundbrunnen 2025-01-01 07:00:00          7.21        86
# 8   Berlin Gesundbrunnen 2025-01-01 08:00:00          7.00        85
# 9   Berlin Gesundbrunnen 2025-01-01 09:00:00          7.56        83
# 10  Berlin Gesundbrunnen 2025-01-01 10:00:00          7.61        83
# 11  Berlin Gesundbrunnen 2025-01-01 11:00:00          7.61        81
# 12  Berlin Gesundbrunnen 2025-01-01 12:00:00          7.61        81
# 13  Berlin Gesundbrunnen 2025-01-01 13:00:00          7.62        83
# 14  Berlin Gesundbrunnen 2025-01-01 14:00:00          7.20        84
#
#     wind_speed          weather  rain_amount  snow_amount
# 0        11.09  overcast clouds         0.00          0.0
# 1        11.53  overcast clouds         0.00          0.0
# 2        11.70       light rain         0.42          0.0
# 3        11.82    moderate rain         1.33          0.0
# 4        11.61    moderate rain         2.37          0.0
# 5        11.95       light rain         0.13          0.0
# 6        12.80       light rain         0.52          0.0
# 7        12.91       light rain         0.73          0.0
# 8        13.43       light rain         0.60          0.0
# 9        13.76       light rain         0.18          0.0
# 10       13.64    moderate rain         1.26          0.0
# 11       13.55       light rain         0.65          0.0
# 12       13.63    moderate rain         1.09          0.0
# 13       13.66    moderate rain         1.15          0.0
# 14       13.77    moderate rain         1.54          0.0

# %%
# save the DataFrame to a parquet file (!!!!!DO NOT USE UNLESS YOU WANT TO OVERWRITE THE FILE!!!!!)
#df.to_parquet('../../data/weather_data/weather_data.parquet', index=False)

# %% [markdown]
# # Explore created DataFrame from pipeline

# %%
# Load the DataFrame from parquet file
df = pd.read_parquet('../../data/weather_data/weather_data.parquet')

# %%
df.shape
# Out:
# (393609, 8)

# %%
df.head(15)
# Out:
#                  station                time  temp_celsius  humidity  \
# 0   Berlin Gesundbrunnen 2025-01-01 00:00:00          4.36        93
# 1   Berlin Gesundbrunnen 2025-01-01 01:00:00          4.84        81
# 2   Berlin Gesundbrunnen 2025-01-01 02:00:00          5.45        83
# 3   Berlin Gesundbrunnen 2025-01-01 03:00:00          5.42        84
# 4   Berlin Gesundbrunnen 2025-01-01 04:00:00          5.92        84
# 5   Berlin Gesundbrunnen 2025-01-01 05:00:00          6.53        86
# 6   Berlin Gesundbrunnen 2025-01-01 06:00:00          6.59        87
# 7   Berlin Gesundbrunnen 2025-01-01 07:00:00          7.21        86
# 8   Berlin Gesundbrunnen 2025-01-01 08:00:00          7.00        85
# 9   Berlin Gesundbrunnen 2025-01-01 09:00:00          7.56        83
# 10  Berlin Gesundbrunnen 2025-01-01 10:00:00          7.61        83
# 11  Berlin Gesundbrunnen 2025-01-01 11:00:00          7.61        81
# 12  Berlin Gesundbrunnen 2025-01-01 12:00:00          7.61        81
# 13  Berlin Gesundbrunnen 2025-01-01 13:00:00          7.62        83
# 14  Berlin Gesundbrunnen 2025-01-01 14:00:00          7.20        84
#
#     wind_speed          weather  rain_amount  snow_amount
# 0        11.09  overcast clouds         0.00          0.0
# 1        11.53  overcast clouds         0.00          0.0
# 2        11.70       light rain         0.42          0.0
# 3        11.82    moderate rain         1.33          0.0
# 4        11.61    moderate rain         2.37          0.0
# 5        11.95       light rain         0.13          0.0
# 6        12.80       light rain         0.52          0.0
# 7        12.91       light rain         0.73          0.0
# 8        13.43       light rain         0.60          0.0
# 9        13.76       light rain         0.18          0.0
# 10       13.64    moderate rain         1.26          0.0
# 11       13.55       light rain         0.65          0.0
# 12       13.63    moderate rain         1.09          0.0
# 13       13.66    moderate rain         1.15          0.0
# 14       13.77    moderate rain         1.54          0.0
