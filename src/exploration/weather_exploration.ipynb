# %% [markdown]
# # Weather Exploration

# %%
# Import libraries
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## This does not work anymore because the json is too big for GitHub. See below for new code to load the data.

# %%
# Load weather data from json
#df_weather = pd.read_json('../weatherdata/data_scraping/scrapedData/scrapedData.json')
with open('../weatherdata/data_scraping/scrapedData/scrapedData.json', 'r') as file:
    data = pd.read_json(file)

# %%
# transform the data to a more usable format
records = []
for station, entries in data.items():
    for entry in entries:
        dt = datetime.fromtimestamp(entry['dt'])
        temp_k = entry['main']['temp']
        temp_c = temp_k - 273.15  # Convert from Kelvin to Celsius
        weather_desc = entry['weather'][0]['description'] if entry.get('weather') else None
        rain_amount = entry.get('rain', {}).get('1h', 0.0)
        snow_amount = entry.get('snow', {}).get('1h', 0.0)
        humidity = entry['main']['humidity']
        wind_speed = entry['wind']['speed']
        records.append({
            'station': station,
            'time': dt,
            'temp_celsius': round(temp_c, 2),
            'humidity': humidity,
            'wind_speed': wind_speed,
            'weather': weather_desc,
            'rain_amount': rain_amount,
            'snow_amount': snow_amount
        })

# Create DataFrame
df = pd.DataFrame(records)

# %%
df.shape

# %%
df.info()

# %%
# Display first 5 rows
df.head(15)

# %%
# save the DataFrame to a parquet file (!!!!!DO NOT USE UNLESS YOU WANT TO OVERWRITE THE FILE!!!!!)
#df.to_parquet('../../data/weather_data/weather_data.parquet', index=False)

# %% [markdown]
# # Explore created DataFrame after transformation

# %%
# Load the DataFrame from parquet file
df = pd.read_parquet('../../data/weather_data/weather_data.parquet')

# %%
df.shape
# Out:
# (892223, 8)

# %%
df.head(15)
# Out:
#                  station                time  temp_celsius  humidity  \
# 0   Berlin Gesundbrunnen 2024-08-01 00:00:00         15.87        87
# 1   Berlin Gesundbrunnen 2024-08-01 01:00:00         14.80        86
# 2   Berlin Gesundbrunnen 2024-08-01 02:00:00         14.12        89
# 3   Berlin Gesundbrunnen 2024-08-01 03:00:00         14.02        90
# 4   Berlin Gesundbrunnen 2024-08-01 04:00:00         13.68        92
# 5   Berlin Gesundbrunnen 2024-08-01 05:00:00         13.69        93
# 6   Berlin Gesundbrunnen 2024-08-01 06:00:00         12.91        93
# 7   Berlin Gesundbrunnen 2024-08-01 07:00:00         13.55        89
# 8   Berlin Gesundbrunnen 2024-08-01 08:00:00         15.32        82
# 9   Berlin Gesundbrunnen 2024-08-01 09:00:00         17.62        79
# 10  Berlin Gesundbrunnen 2024-08-01 10:00:00         18.45        79
# 11  Berlin Gesundbrunnen 2024-08-01 11:00:00         18.94        79
# 12  Berlin Gesundbrunnen 2024-08-01 12:00:00         20.55        61
# 13  Berlin Gesundbrunnen 2024-08-01 13:00:00         21.85        56
# 14  Berlin Gesundbrunnen 2024-08-01 14:00:00         22.54        58
#
#     wind_speed           weather  rain_amount  snow_amount
# 0         3.26  scattered clouds          0.0          0.0
# 1         2.86  scattered clouds          0.0          0.0
# 2         2.84  scattered clouds          0.0          0.0
# 3         2.78         clear sky          0.0          0.0
# 4         2.96         clear sky          0.0          0.0
# 5         3.04         clear sky          0.0          0.0
# 6         3.04         clear sky          0.0          0.0
# 7         2.81         clear sky          0.0          0.0
# 8         3.78        few clouds          0.0          0.0
# 9         3.45  scattered clouds          0.0          0.0
# 10        2.78  scattered clouds          0.0          0.0
# 11        2.27  scattered clouds          0.0          0.0
# 12        1.67  scattered clouds          0.0          0.0
# 13        1.67  scattered clouds          0.0          0.0
# 14        2.08     broken clouds          0.0          0.0

# %%
# Display all stations names
df['station'].unique()
# Out:
# array(['Berlin Gesundbrunnen', 'Berlin Südkreuz',
#        'Berlin Potsdamer Platz', 'Berlin Hbf', 'Paderborn Hbf',
#        'Hamm(Westf)Hbf', 'Hamburg Hbf', 'Hamburg Dammtor',
#        'Karlsruhe Hbf', 'Würzburg Hbf', 'Bietigheim-Bissingen',
#        'Berlin-Lichtenberg', 'Berlin Ostkreuz', 'Berlin Ostbahnhof',
#        'Berlin Friedrichstraße', 'Landshut(Bay)Hbf', 'Weimar',
#        'Flughafen BER', 'Frankfurt(Main)Süd', 'Hamburg-Altona',
#        'Essen Hbf', 'Frankfurt(Main)Hbf', 'Düsseldorf Hbf', 'Neuss Hbf',
#        'Köln Hbf', 'Kassel Hbf', 'München Ost', 'München Hbf', 'Gießen',
#        'Hildesheim Hbf', 'München-Pasing', 'Aachen Hbf',
#        'Mönchengladbach Hbf', 'Köln Messe/Deutz', 'Erfurt Hbf',
#        'Nürnberg Hbf', 'Bochum Hbf', 'Frankfurt(Oder)', 'Hanau Hbf',
#        'Wuppertal Hbf', 'Mainz Hbf', 'Duisburg Hbf', 'Oberhausen Hbf',
#        'Gelsenkirchen Hbf', 'Münster(Westf)Hbf', 'Dortmund Hbf',
#        'Göttingen', 'Bielefeld Hbf', 'Herford', 'Stuttgart Hbf',
#        'Heidelberg Hbf', 'Darmstadt Hbf', 'Fulda', 'Halle(Saale)Hbf',
#        'Aschaffenburg Hbf', 'Bremen Hbf', 'Dresden-Neustadt',
#        'Dresden Hbf', 'Hamburg-Harburg', 'Lüneburg',
#        'Berlin Zoologischer Garten', 'Potsdam Hbf', 'Berlin-Wannsee',
#        'Koblenz Hbf', 'Oldenburg(Oldb)Hbf', 'Hannover Hbf',
#        'Braunschweig Hbf', 'Magdeburg Hbf', 'Leipzig Hbf',
#        'Berlin-Spandau', 'Augsburg Hbf', 'Cottbus Hbf', 'Plochingen',
#        'Trier Hbf', 'Pforzheim Hbf', 'Wiesbaden Hbf', 'Mannheim Hbf',
#        'Neustadt(Weinstr)Hbf', 'Kaiserslautern Hbf', 'Saarbrücken Hbf',
#        'Kiel Hbf', 'Hagen Hbf', 'Wolfsburg Hbf', 'Ulm Hbf', 'Bruchsal',
#        'Worms Hbf', 'Ludwigshafen(Rh)Hbf', 'Bamberg', 'Fürth(Bay)Hbf',
#        'Osnabrück Hbf', 'Bonn Hbf', 'Tübingen Hbf', 'Offenburg', 'Rheine',
#        'Neumünster', 'Lübeck Hbf', 'Solingen Hbf', 'Chemnitz Hbf',
#        'Uelzen', 'Kassel-Wilhelmshöhe', 'Regensburg Hbf',
#        'Singen(Hohentwiel)', 'Ingolstadt Hbf', 'Freiburg(Breisgau) Hbf',
#        'Bad Oldesloe', 'Rosenheim', 'Rostock Hbf'], dtype=object)
