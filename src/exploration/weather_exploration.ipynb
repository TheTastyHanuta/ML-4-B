# %% [markdown]
# # Weather Exploration

# %%
# Import libraries
import pandas as pd
from datetime import datetime

# %%
# Load weather data from json
#df_weather = pd.read_json('../weatherdata/data_scraping/scrapedData/scrapedData.json')
with open('../weatherdata/data_scraping/scrapedData/scrapedData.json', 'r') as file:
    data = pd.read_json(file)

# %%
# transform the data to a more usable format
records = []
for station, entries in data.items():
    for entry in entries:
        dt = datetime.fromtimestamp(entry['dt'])
        temp_k = entry['main']['temp']
        temp_c = temp_k - 273.15  # Convert from Kelvin to Celsius
        weather_desc = entry['weather'][0]['description'] if entry.get('weather') else None
        rain_amount = entry.get('rain', {}).get('1h', 0.0)
        records.append({
            'station': station,
            'time': dt,
            'temp_celsius': round(temp_c, 2),
            'weather': weather_desc,
            'rain_amount': rain_amount
        })

# Create DataFrame
df = pd.DataFrame(records)

# %%
# Display first 5 rows
df.head(15)
# Out:
#                  station                time  temp_celsius          weather  \
# 0   Berlin Gesundbrunnen 2025-01-01 00:00:00          4.36  overcast clouds
# 1   Berlin Gesundbrunnen 2025-01-01 01:00:00          4.84  overcast clouds
# 2   Berlin Gesundbrunnen 2025-01-01 02:00:00          5.45       light rain
# 3   Berlin Gesundbrunnen 2025-01-01 03:00:00          5.42    moderate rain
# 4   Berlin Gesundbrunnen 2025-01-01 04:00:00          5.92    moderate rain
# 5   Berlin Gesundbrunnen 2025-01-01 05:00:00          6.53       light rain
# 6   Berlin Gesundbrunnen 2025-01-01 06:00:00          6.59       light rain
# 7   Berlin Gesundbrunnen 2025-01-01 07:00:00          7.21       light rain
# 8   Berlin Gesundbrunnen 2025-01-01 08:00:00          7.00       light rain
# 9   Berlin Gesundbrunnen 2025-01-01 09:00:00          7.56       light rain
# 10  Berlin Gesundbrunnen 2025-01-01 10:00:00          7.61    moderate rain
# 11  Berlin Gesundbrunnen 2025-01-01 11:00:00          7.61       light rain
# 12  Berlin Gesundbrunnen 2025-01-01 12:00:00          7.61    moderate rain
# 13  Berlin Gesundbrunnen 2025-01-01 13:00:00          7.62    moderate rain
# 14  Berlin Gesundbrunnen 2025-01-01 14:00:00          7.20    moderate rain
#
#     rain_amount
# 0          0.00
# 1          0.00
# 2          0.42
# 3          1.33
# 4          2.37
# 5          0.13
# 6          0.52
# 7          0.73
# 8          0.60
# 9          0.18
# 10         1.26
# 11         0.65
# 12         1.09
# 13         1.15
# 14         1.54

# %%
# save the DataFrame to a parquet file
df.to_parquet('../../data/weather_data.parquet', index=False)
